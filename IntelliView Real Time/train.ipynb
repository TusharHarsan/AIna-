# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# # Train the model
# train_results = model.train(
#     data="C:/Users/savit/Downloads/CS 231N Project.v2i.yolov11/data.yaml",  # path to dataset YAML
#     epochs=50,  # number of training epochs
#     imgsz=640,  # training image size
#     device=0,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
# )

# %%
model = YOLO("C:/Users/savit/Downloads/CS 231N Project.v2i.yolov11/runs/detect/train6/weights/best.pt")
results = model("gun1.mp4", save=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1360) c:\Users\savit\OneDrive\Desktop\Finale GFG Hackfest Project\IntelliView Real Time\gun1.mp4: 384x640 (no detections), 91.4ms
# video 1/1 (frame 2/1360) c:\Users\savit\OneDrive\Desktop\Finale GFG Hackfest Project\IntelliView Real Time\gun1.mp4: 384x640 (no detections), 42.0ms
# ...

# %%
from ultralytics import YOLO
import cv2

# Load the trained YOLO model
model = YOLO("C:/Users/savit/Downloads/CS 231N Project.v2i.yolov11/runs/detect/train6/weights/best.pt")
# model=YOLO("yolo11n.pt")

# Initialize webcam
cap = cv2.VideoCapture(0)  # 0 for default webcam

# Check if the webcam is opened successfully
if not cap.isOpened():
    print("Error: Could not open webcam")
    exit()

while True:
    # Read frame from webcam
    ret, frame = cap.read()
    
    if not ret:
        print("Failed to grab frame")
        break
        
    # Run YOLOv8 inference on the frame
    results = model(frame)
    
    # Visualize the results on the frame
    annotated_frame = results[0].plot()
    
    # Display the frame
    cv2.imshow("YOLOv8 Detection", annotated_frame)
    
    # Break the loop if 'q' is pressed
    # Wait for 30ms between frames
    if cv2.waitKey(30) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.5ms
# Speed: 4.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
